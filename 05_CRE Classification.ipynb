# %% [markdown]
# # 1.4 CRE Classification
# <h3> Can CREs be grouped into distinct classes based on signal level and cross-cell variability? Within all cell types or lineage specific? </h3>

# %% [markdown]
# ## CRE Classification based on signal level and cross-cell variability on lineage-specific γδ T cells

# %% [markdown]
# ### Preparing Dataset

# %% [markdown]
# ATACseq data from lineage-specific γδ T cells

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from pathlib import Path

ATAC_seq = pd.read_csv('data/ATAC_pfiltered.csv')

ATAC_seq_gd_path = Path('data') / 'ATAC_seq_gd.csv'
ATAC_seq_gd = pd.read_csv(ATAC_seq_gd_path)
ATAC_seq_gd.head()
# Out:
#    ImmGenATAC1219.peakID chrom   Summit  mm10.60way.phastCons_scores  \
# 0  ImmGenATAC1219.peak_3  chr1  3120109                         0.07
# 1  ImmGenATAC1219.peak_4  chr1  3121485                         0.15
# 2  ImmGenATAC1219.peak_5  chr1  3372787                         0.03
# 3  ImmGenATAC1219.peak_6  chr1  3399217                         0.06
# 4  ImmGenATAC1219.peak_7  chr1  3400115                         0.44
#
#    _-log10_bestPvalue  Included.in.systematic.analysis  TSS  \
# 0               10.80                              1.0  NaN
# 1                3.02                              1.0  NaN
# 2                1.31                              NaN  NaN
# 3                2.39                              1.0  NaN
# 4                2.57                              1.0  NaN
#
#   genes.within.100Kb  MPP4.135+.BM  preT.DN1.Th  ...  preT.DN2b.Th  \
# 0                NaN          0.11         0.40  ...          0.11
# 1                NaN          0.11         0.46  ...          0.47
# 2                NaN          0.11         0.77  ...          1.34
# 3                NaN          1.58         0.77  ...          0.47
# 4                NaN          0.11         0.40  ...          0.47
#
#    preT.DN3.Th  T.DN4.Th  Tgd.g1.1+d1.24a+.Th  Tgd.g2+d1.24a+.Th  \
# 0         0.10      0.35                 0.11               0.76
# 1         0.10      0.58                 0.11               0.29
# 2         1.69      0.34                 1.39               1.58
# 3         1.02      0.10                 1.33               0.10
# 4         0.10      0.58                 1.33               1.27
#
#    Tgd.g2+d17.24a+.Th  Tgd.Sp  Tgd.g1.1+d1.LN  Tgd.g2+d1.LN  Tgd.g2+d17.LN
# 0                0.53    1.46            0.11          0.12           0.86
# 1                0.53    0.51            0.11          0.70           0.13
# 2                3.16    0.51            0.99          0.12           0.73
# 3                1.48    0.15            0.11          1.26           0.73
# 4                1.11    0.51            2.86          0.70           0.73
#
# [5 rows x 21 columns]

# %% [markdown]
# Removing annotation columns

# %%
annotation_cols = [
    "Summit",
    "chrom",
    "mm10.60way.phastCons_scores",
    "_-log10_bestPvalue",
    "Included.in.systematic.analysis",
    "TSS",
    "genes.within.100Kb"
]

ATAC_signal_Tgd = ATAC_seq_gd.drop(columns=annotation_cols)
ATAC_signal_Tgd.shape
# Out:
# (362330, 14)

# %%
annotation_col = [
    "ImmGenATAC1219.peakID"	
] 
    

ATAC_signal_Tgd_numeric = ATAC_signal_Tgd.drop(columns=annotation_col).copy()
ATAC_signal_Tgd_numeric.shape
# Out:
# (362330, 13)

# %% [markdown]
# ### Clustering of Peaks (CREs) based on lineage-specific γδ T-cells

# %% [markdown]
# Calculating mean signal and variance across γδ T cells for every peak

# %%
peak_mean_Tgd = ATAC_signal_Tgd_numeric.mean(axis=1) # Mittelwert über alle Tgd-Zelltypen für jeden peak

peak_var_Tgd = ATAC_signal_Tgd_numeric.var(axis=1) # Varianz über alle Tgd-Zelltypen für jeden peak

#varianz und std sind redundant --> weiter mit Varianz
cre_parameter = pd.DataFrame(
    {"mean_signal": peak_mean_Tgd, "var": peak_var_Tgd})

cre_parameter.index = ATAC_signal_Tgd["ImmGenATAC1219.peakID"]
cre_parameter.head()
# Out:
#                        mean_signal       var
# ImmGenATAC1219.peakID
# ImmGenATAC1219.peak_3     0.445385  0.174927
# ImmGenATAC1219.peak_4     0.323846  0.049659
# ImmGenATAC1219.peak_5     1.043846  0.676209
# ImmGenATAC1219.peak_6     0.759231  0.298691
# ImmGenATAC1219.peak_7     0.846923  0.516406

# %% [markdown]
# <h3> K-means clustering </h3>
# K-means clustering is applied to mean signal and variance to group CREs by average accessibility and across-cell variability. Due to the large dataset size, a sample size of 10000 is used for silhouette score evaluation.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler
import seaborn as sns

#Spaltenweise z-transformation
X_z = StandardScaler().fit_transform(cre_parameter)

silhouette_scores = []
k_values = range(2, 10)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42,  n_init=20)
    labels = kmeans.fit_predict(X_z)
    score = silhouette_score(X_z, labels, sample_size=10000, random_state=42)    
    silhouette_scores.append(score)
    print(f"k={k}: silhouette score = {score:.4f}")

best_k = k_values[np.argmax(silhouette_scores)] #index mit größten Wert zurück
print(f"\nBest number of clusters according to silhouette score: k={best_k}")
# Out:
# k=2: silhouette score = 0.8932
# k=3: silhouette score = 0.8527
# k=4: silhouette score = 0.8290
# k=5: silhouette score = 0.8192
# k=6: silhouette score = 0.7548
# k=7: silhouette score = 0.7635
# k=8: silhouette score = 0.7071
# k=9: silhouette score = 0.7152
#
# Best number of clusters according to silhouette score: k=2

# %% [markdown]
# Silhouette score plot for K-means clustering.

# %%
plt.figure(figsize=(8, 4))
plt.plot(list(k_values), silhouette_scores, color="steelblue")
plt.xticks(list(k_values))
plt.xlabel("Number of clusters k")
plt.ylabel("Silhouette score")
plt.title("Silhouette score for KMeans on ATAC peaks data")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# Although the highest score is achieved  by k=2, k=4 is selected for better biological interpretability.

# %% [markdown]
# ### Selecting k=4 and visualizing cluster profiles

# %%
best_k = 4
kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=20)
labels = kmeans.fit_predict(X_z)
cre_parameter['cluster'] = labels

# %% [markdown]
# Scatter Plot of CRE Classification across lineage-specific γδ T-cells

# %%
plt.figure(figsize=(8, 4))

sns.scatterplot(
    data=cre_parameter, 
    x="mean_signal", 
    y="var", 
    hue="cluster", 
    palette= sns.cubehelix_palette(as_cmap=True),  
    alpha=0.6,
    edgecolor=None
)

plt.xlabel("Mean Signal")
plt.ylabel("Variance")
plt.title("CRE classification signal level and variability (Tgd-cells)")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# Calculating the average mean signal and variance for each cluster.

# %%
cre_parameter.groupby('cluster')[['mean_signal','var']].mean()
# Out:
#          mean_signal          var
# cluster
# 0           2.950395     6.600423
# 1          47.784021  1095.376006
# 2          78.615706   284.747612
# 3          24.103514   144.105627

# %% [markdown]
# Variance of mean signal and variance within each cluster.

# %%
cre_parameter.groupby('cluster')[['mean_signal','var']].var()
# Out:
#          mean_signal            var
# cluster
# 0           8.637740     179.476113
# 1        1011.435692  357918.264566
# 2         955.319982   26312.614766
# 3         107.190215   12104.448146

# %% [markdown]
# Summary statistics for mean signal and variance within each cluster.

# %%
cre_parameter.groupby('cluster')[['mean_signal', 'var']].describe()
# Out:
#         mean_signal                                                         \
#               count       mean        std        min        25%        50%
# cluster
# 0          335344.0   2.950395   2.939003   0.122308   1.050000   1.801538
# 1            1065.0  47.784021  31.803077  11.444615  27.388462  38.027692
# 2            3593.0  78.615706  30.908251  36.566923  58.936923  69.630769
# 3           22328.0  24.103514  10.353271   4.530000  16.725192  21.755000
#
#                                      var                                       \
#                75%         max     count         mean         std         min
# cluster
# 0         3.663077   19.559231  335344.0     6.600423   13.396870    0.001036
# 1        56.181538  282.133077    1065.0  1095.376006  598.262705  630.890064
# 2        89.642308  727.420000    3593.0   284.747612  162.211636    0.000000
# 3        30.036154   58.420769   22328.0   144.105627  110.020217    6.941797
#
#
#                 25%         50%          75%          max
# cluster
# 0          0.619523    1.622886     5.682626   163.624803
# 1        757.282823  905.862876  1184.707124  6769.374424
# 2        161.349926  247.787659   380.301927  1421.003610
# 3         67.165475  110.955406   183.069428   648.230000

# %% [markdown]
# <p> A cluster number of k=4 was chosen. By testing k=2 to 5, it was shown that 4 is the most logical choice. </p>
# Cluster 0 (335,344 values): Very low mean and variance (mostly closed CREs).<br>Cluster 3 (22,328 values): Low mean and low-to-medium variance (weakly active CREs).<br>Cluster 2 (3,593 values): High mean and high variance (strongly active CREs).<br>Cluster 1 (1,065 values): Very high mean and variance (very strongly active CREs).<br>
# <br>Notably, almost all CREs are grouped into Cluster 0, by which it is indicated that most are kept inactive or closed across the differentiation of the γδ T-cell lineage.

# %% [markdown]
# <h3>Boxplot of mean ATACseq signal per cluster</h3>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=cre_parameter, x='cluster', y='mean_signal', color='violet')
plt.title('Mean ATAC signal per CRE cluster (Tγδ)')
plt.show()

# %% [markdown]
# <h3>Boxplot of ATACseq signal variance per cluster</h3>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=cre_parameter, x='cluster', y='var', color='violet')
plt.title('Varianz ATAC signal per CRE cluster (Tγδ)')
plt.show()

# %% [markdown]
# A clear separation of the clusters is confirmed by the boxplot based on their average accessibility. Inactive or closed regions are represented by Cluster 0, while a slight increase is shown by Cluster 3. Moderately active regions are captured by Cluster 1 and the most intensely open chromatin regions with the highest average signal are clearly contained within Cluster 2.

# %% [markdown]
# Heatmap of average accessibility per γδ T-cell sample for each cluster

# %% [markdown]
# Adding Cluster Labels to ATACseq Data

# %%
ATAC_signal_Tgd_numeric = ATAC_signal_Tgd.set_index('ImmGenATAC1219.peakID') #ImmGenATAC1219.peakID als index so das cluster_parameter und ATAC daten gleichen index haben
ATAC_signal_Tgd_numeric_cluster = ATAC_signal_Tgd_numeric.copy()
ATAC_signal_Tgd_numeric_cluster['cluster'] = cre_parameter['cluster'] #neue splate ATAC daten mit clustern von Cre parameter übernommen

ATAC_signal_Tgd_numeric_cluster.head()
# Out:
#                        MPP4.135+.BM  preT.DN1.Th  preT.DN2a.Th  preT.DN2b.Th  \
# ImmGenATAC1219.peakID
# ImmGenATAC1219.peak_3          0.11         0.40          0.77          0.11
# ImmGenATAC1219.peak_4          0.11         0.46          0.11          0.47
# ImmGenATAC1219.peak_5          0.11         0.77          0.84          1.34
# ImmGenATAC1219.peak_6          1.58         0.77          0.77          0.47
# ImmGenATAC1219.peak_7          0.11         0.40          0.84          0.47
#
#                        preT.DN3.Th  T.DN4.Th  Tgd.g1.1+d1.24a+.Th  \
# ImmGenATAC1219.peakID
# ImmGenATAC1219.peak_3         0.10      0.35                 0.11
# ImmGenATAC1219.peak_4         0.10      0.58                 0.11
# ImmGenATAC1219.peak_5         1.69      0.34                 1.39
# ImmGenATAC1219.peak_6         1.02      0.10                 1.33
# ImmGenATAC1219.peak_7         0.10      0.58                 1.33
#
#                        Tgd.g2+d1.24a+.Th  Tgd.g2+d17.24a+.Th  Tgd.Sp  \
# ImmGenATAC1219.peakID
# ImmGenATAC1219.peak_3               0.76                0.53    1.46
# ImmGenATAC1219.peak_4               0.29                0.53    0.51
# ImmGenATAC1219.peak_5               1.58                3.16    0.51
# ImmGenATAC1219.peak_6               0.10                1.48    0.15
# ImmGenATAC1219.peak_7               1.27                1.11    0.51
#
#                        Tgd.g1.1+d1.LN  Tgd.g2+d1.LN  Tgd.g2+d17.LN  cluster
# ImmGenATAC1219.peakID
# ImmGenATAC1219.peak_3            0.11          0.12           0.86        0
# ImmGenATAC1219.peak_4            0.11          0.70           0.13        0
# ImmGenATAC1219.peak_5            0.99          0.12           0.73        0
# ImmGenATAC1219.peak_6            0.11          1.26           0.73        0
# ImmGenATAC1219.peak_7            2.86          0.70           0.73        0

# %% [markdown]
# Grouping ATACseq data by Cluster Assignments

# %%
cluster_sample_mean = (
    ATAC_signal_Tgd_numeric_cluster
    .groupby('cluster')
    .mean()
)
cluster_sample_mean.head()
# Out:
#          MPP4.135+.BM  preT.DN1.Th  preT.DN2a.Th  preT.DN2b.Th  preT.DN3.Th  \
# cluster
# 0            3.203880     3.077105      3.022833      2.963649     2.970361
# 1           57.904638    60.100347     60.771465     52.966338    44.931221
# 2           72.950596    76.515825     77.327370     78.618505    79.006735
# 3           23.339158    24.336383     24.634558     24.829462    24.322645
#
#           T.DN4.Th  Tgd.g1.1+d1.24a+.Th  Tgd.g2+d1.24a+.Th  \
# cluster
# 0         2.982815             2.960293           2.890313
# 1        35.725681            45.908441          45.390930
# 2        79.869438            79.097286          80.630810
# 3        24.094394            24.344642          24.220262
#
#          Tgd.g2+d17.24a+.Th     Tgd.Sp  Tgd.g1.1+d1.LN  Tgd.g2+d1.LN  \
# cluster
# 0                  2.908988   2.913996        2.840997      2.827425
# 1                 46.418535  39.474357       42.281202     44.131221
# 2                 80.649004  81.190409       80.863270     79.908839
# 3                 24.461671  24.507286       24.053106     24.164920
#
#          Tgd.g2+d17.LN
# cluster
# 0             2.792482
# 1            45.187897
# 2            75.376084
# 3            22.037195

# %% [markdown]
# Heatmap: Mean accessibility per lineage-specific cell sample for each cluster

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(
    cluster_sample_mean, #Zeilen --> x-Achse, Spalten --> y-Achse, cluster spalte index nicht mitgenommen
    cmap="viridis"
)

plt.title('Mean accessibility per Tγδ sample for each CRE cluster')
plt.xlabel('Tγδ samples')
plt.ylabel('CRE cluster')
plt.show()

# %% [markdown]
# While it was shown by the scatter plots that Cluster 1 varies, a possible biological pattern behind this variance is revealed by the heatmap.
# It is indicated by the sharp drop in accessibility at the strongly active and high-variance cluster specifically at the T.DN4.Th stage indicates that specific genomic regions could be temporarily repressed by these elements during thymic development before they are reactivated in mature peripheral Tγδ cells.

# %% [markdown]
# ## CRE Classification based on signal level and cross-cell variability within all cell types

# %% [markdown]
# ### Preparing Dataset

# %% [markdown]
# ATACseq data from all cell types

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from pathlib import Path

ATAC_pfiltered_path = Path('data') / 'ATAC_pfiltered.csv'
ATAC_seq = pd.read_csv(ATAC_pfiltered_path)
ATAC_seq
# Out:
#              ImmGenATAC1219.peakID chrom    Summit  \
# 0            ImmGenATAC1219.peak_3  chr1   3120109
# 1            ImmGenATAC1219.peak_4  chr1   3121485
# 2            ImmGenATAC1219.peak_5  chr1   3372787
# 3            ImmGenATAC1219.peak_6  chr1   3399217
# 4            ImmGenATAC1219.peak_7  chr1   3400115
# ...                            ...   ...       ...
# 362325  ImmGenATAC1219.peak_512589  chrY  90811728
# 362326  ImmGenATAC1219.peak_512590  chrY  90812084
# 362327  ImmGenATAC1219.peak_512591  chrY  90812450
# 362328  ImmGenATAC1219.peak_512592  chrY  90812906
# 362329  ImmGenATAC1219.peak_512595  chrY  90828985
#
#         mm10.60way.phastCons_scores  _-log10_bestPvalue  \
# 0                              0.07               10.80
# 1                              0.15                3.02
# 2                              0.03                1.31
# 3                              0.06                2.39
# 4                              0.44                2.57
# ...                             ...                 ...
# 362325                         0.00                2.33
# 362326                         0.00                3.12
# 362327                         0.00                3.99
# 362328                         0.00                3.21
# 362329                         0.00                1.41
#
#         Included.in.systematic.analysis  TSS genes.within.100Kb  LTHSC.34-.BM  \
# 0                                   1.0  NaN                NaN          2.36
# 1                                   1.0  NaN                NaN          0.41
# 2                                   NaN  NaN                NaN          0.41
# 3                                   1.0  NaN                NaN          2.36
# 4                                   1.0  NaN                NaN          0.41
# ...                                 ...  ...                ...           ...
# 362325                              1.0  NaN              Erdr1          0.41
# 362326                              1.0  NaN              Erdr1          2.36
# 362327                              1.0  NaN              Erdr1          4.37
# 362328                              1.0  NaN              Erdr1          0.41
# 362329                              NaN  NaN              Erdr1          0.41
#
#         LTHSC.34+.BM  ...  DC.4+.Sp  DC.8+.Sp  DC.pDC.Sp  DC.103+11b+.SI  \
# 0               0.10  ...      0.87      0.54       2.72            0.95
# 1               0.10  ...      0.44      1.83       0.66            0.11
# 2               0.10  ...      0.44      0.10       0.66            1.79
# 3               1.64  ...      1.34      0.29       0.23            0.89
# 4               0.10  ...      0.87      1.93       0.59            0.11
# ...              ...  ...       ...       ...        ...             ...
# 362325          7.41  ...      4.98      4.47       2.83            4.93
# 362326          8.79  ...      4.03      4.07       5.87            5.36
# 362327          8.79  ...      3.81      3.34       4.27            6.73
# 362328          7.41  ...      4.28      5.55       4.15            6.88
# 362329          0.71  ...      1.26      0.72       0.71            1.40
#
#         DC.103+11b-.SI  FRC.SLN  IAP.SLN  BEC.SLN  LEC.SLN  Ep.MEChi.Th
# 0                 0.11    63.38     8.92     1.33     1.04         0.11
# 1                 0.92    13.50     0.98     1.28     1.04         0.11
# 2                 0.51     0.92     0.75     1.33     1.61         4.50
# 3                 0.11     0.53     1.40     0.90     2.87         9.09
# 4                 1.39     2.58     0.75     2.30     2.34        11.02
# ...                ...      ...      ...      ...      ...          ...
# 362325            4.92     5.13     9.13     2.21     6.53         6.11
# 362326            3.99     7.12     3.57     2.64     5.59         3.64
# 362327            5.53     7.21     5.96     5.17     6.53         6.11
# 362328            7.16     6.21     8.75     6.83     8.14         4.64
# 362329            0.52     0.85     1.37     0.57     0.11         0.50
#
# [362330 rows x 98 columns]

# %% [markdown]
# Removing annotation columns

# %%
annotation_cols = [
    "Summit",
    "chrom",
    "mm10.60way.phastCons_scores",
    "_-log10_bestPvalue",
    "Included.in.systematic.analysis",
    "TSS",
    "genes.within.100Kb"
]

ATAC_signal_all = ATAC_seq.drop(columns=annotation_cols)
ATAC_signal_all
# Out:
#              ImmGenATAC1219.peakID  LTHSC.34-.BM  LTHSC.34+.BM  STHSC.150-.BM  \
# 0            ImmGenATAC1219.peak_3          2.36          0.10           0.90
# 1            ImmGenATAC1219.peak_4          0.41          0.10           0.11
# 2            ImmGenATAC1219.peak_5          0.41          0.10           0.11
# 3            ImmGenATAC1219.peak_6          2.36          1.64           1.85
# 4            ImmGenATAC1219.peak_7          0.41          0.10           0.11
# ...                            ...           ...           ...            ...
# 362325  ImmGenATAC1219.peak_512589          0.41          7.41           1.85
# 362326  ImmGenATAC1219.peak_512590          2.36          8.79           0.90
# 362327  ImmGenATAC1219.peak_512591          4.37          8.79           3.52
# 362328  ImmGenATAC1219.peak_512592          0.41          7.41           3.52
# 362329  ImmGenATAC1219.peak_512595          0.41          0.71           0.90
#
#         MPP4.135+.BM  proB.CLP.BM  proB.FrA.BM  proB.FrBC.BM  preB.FrD.BM  \
# 0               0.11         0.47         0.10          0.50         1.17
# 1               0.11         0.79         0.40          0.50         2.23
# 2               0.11         0.47         0.34          1.78         1.17
# 3               1.58         1.12         0.34          0.42         0.13
# 4               0.11         0.11         1.34          0.90         1.69
# ...              ...          ...          ...           ...          ...
# 362325          3.49         5.76         4.24          7.22         7.60
# 362326          2.15         3.25         2.70          7.86         9.21
# 362327          2.58         4.21         4.83          5.61        10.25
# 362328          3.04         6.46         8.29         12.04         5.29
# 362329          3.49         2.85         0.10          2.31         1.69
#
#         B.FrE.BM  ...  DC.4+.Sp  DC.8+.Sp  DC.pDC.Sp  DC.103+11b+.SI  \
# 0           0.32  ...      0.87      0.54       2.72            0.95
# 1           0.80  ...      0.44      1.83       0.66            0.11
# 2           0.32  ...      0.44      0.10       0.66            1.79
# 3           0.80  ...      1.34      0.29       0.23            0.89
# 4           0.80  ...      0.87      1.93       0.59            0.11
# ...          ...  ...       ...       ...        ...             ...
# 362325      9.80  ...      4.98      4.47       2.83            4.93
# 362326     11.25  ...      4.03      4.07       5.87            5.36
# 362327     13.60  ...      3.81      3.34       4.27            6.73
# 362328      9.11  ...      4.28      5.55       4.15            6.88
# 362329      1.10  ...      1.26      0.72       0.71            1.40
#
#         DC.103+11b-.SI  FRC.SLN  IAP.SLN  BEC.SLN  LEC.SLN  Ep.MEChi.Th
# 0                 0.11    63.38     8.92     1.33     1.04         0.11
# 1                 0.92    13.50     0.98     1.28     1.04         0.11
# 2                 0.51     0.92     0.75     1.33     1.61         4.50
# 3                 0.11     0.53     1.40     0.90     2.87         9.09
# 4                 1.39     2.58     0.75     2.30     2.34        11.02
# ...                ...      ...      ...      ...      ...          ...
# 362325            4.92     5.13     9.13     2.21     6.53         6.11
# 362326            3.99     7.12     3.57     2.64     5.59         3.64
# 362327            5.53     7.21     5.96     5.17     6.53         6.11
# 362328            7.16     6.21     8.75     6.83     8.14         4.64
# 362329            0.52     0.85     1.37     0.57     0.11         0.50
#
# [362330 rows x 91 columns]

# %%
annotation_col = [
    "ImmGenATAC1219.peakID"	
] 
    

ATAC_signal_all_numeric = ATAC_signal_all.drop(columns=annotation_col).copy()
ATAC_signal_all_numeric.shape
# Out:
# (362330, 90)

# %% [markdown]
# ### Clustering of Peaks (CREs) based on all celltypes

# %% [markdown]
# Calculating mean signal and variance across all cell types for every peak

# %%
peak_mean_all = ATAC_signal_all_numeric.mean(axis=1) # Mittelwert über alle Tgd-Zelltypen für jeden peak

peak_var_all = ATAC_signal_all_numeric.var(axis=1) # Varianz über alle Tgd-Zelltypen für jeden peak

#varianz und std sind redundant
cre_parameter_all = pd.DataFrame(
    {"mean_signal": peak_mean_all, "var": peak_var_all})

cre_parameter_all.index = ATAC_signal_all["ImmGenATAC1219.peakID"]
cre_parameter_all
# Out:
#                             mean_signal        var
# ImmGenATAC1219.peakID
# ImmGenATAC1219.peak_3          1.521000  45.111153
# ImmGenATAC1219.peak_4          0.874556   2.352263
# ImmGenATAC1219.peak_5          0.882111   0.666815
# ImmGenATAC1219.peak_6          1.096556   1.485468
# ImmGenATAC1219.peak_7          0.944556   1.593697
# ...                                 ...        ...
# ImmGenATAC1219.peak_512589     5.823889  13.313945
# ImmGenATAC1219.peak_512590     5.526444  16.428241
# ImmGenATAC1219.peak_512591     6.936111  23.891655
# ImmGenATAC1219.peak_512592     6.995111  19.239468
# ImmGenATAC1219.peak_512595     1.751778   2.193738
#
# [362330 rows x 2 columns]

# %% [markdown]
# <h3> K-means clustering </h3>
# K-means clustering is applied to mean signal and variance to group CREs by average accessibility and cross-cell variability. Due to the large dataset size, a sample size of 10000 is used for silhouette score evaluation.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler
import seaborn as sns

#Spaltenweise z-trasnformation
X_z_all = StandardScaler().fit_transform(cre_parameter_all)

silhouette_scores = []
k_values = range(2, 10)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=20)
    labels = kmeans.fit_predict(X_z_all)
    score = silhouette_score(X_z_all, labels, sample_size=10000, random_state=42)    
    silhouette_scores.append(score)
    print(f"k={k}: silhouette score = {score:.4f}")

best_k = k_values[np.argmax(silhouette_scores)]
print(f"\nBeste Clusteranzahl laut Silhouette-Score: k={best_k}")
# Out:
# k=2: silhouette score = 0.8882
# k=3: silhouette score = 0.8288
# k=4: silhouette score = 0.8144
# k=5: silhouette score = 0.8071
# k=6: silhouette score = 0.7825
# k=7: silhouette score = 0.7508
# k=8: silhouette score = 0.7215
# k=9: silhouette score = 0.7002
#
# Beste Clusteranzahl laut Silhouette-Score: k=2

# %% [markdown]
# Silhouette score plot for K-means clustering.

# %%
plt.figure(figsize=(8, 4))
plt.plot(list(k_values), silhouette_scores, color="steelblue")
plt.xticks(list(k_values))
plt.xlabel("Number of clusters k")
plt.ylabel("Silhouette score")
plt.title("Silhouette score for KMeans on ATAC peaks data")
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# Although the highest score is achieved by k=2, k=4 is selected for better biological interpretability and to allow for a direct comparison with the CRE classification for γδ T-cell development.

# %% [markdown]
# ### Selecting k=4 and visualizing cluster profiles

# %%
best_k = 4
kmeans = KMeans(n_clusters=best_k, random_state=42, n_init=20)
labels = kmeans.fit_predict(X_z_all)
cre_parameter_all['cluster'] = labels

# %% [markdown]
# Scatter plot of CRE classification across all samples

# %%
plt.figure(figsize=(8, 4))

sns.scatterplot(
    data=cre_parameter_all, 
    x="mean_signal", 
    y="var", 
    hue="cluster", 
    palette= sns.cubehelix_palette(as_cmap=True),    
    alpha=0.6,
    edgecolor=None
)

plt.xlabel("Mean Signal")
plt.ylabel("Variance")
plt.title("CRE classification signal level and variability (all)")
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# Calculating the average mean signal and variance for each cluster.

# %%
cre_parameter_all.groupby('cluster')[['mean_signal','var']].mean()
# Out:
#          mean_signal          var
# cluster
# 0           3.092382    14.610142
# 1          20.162106   208.506287
# 2          72.148061   394.619013
# 3          53.097032  1374.526879

# %% [markdown]
# Variance of mean signal and variance within each cluster.

# %%
cre_parameter_all.groupby('cluster')[['mean_signal','var']].var()
# Out:
#          mean_signal            var
# cluster
# 0           6.600783     518.319277
# 1          96.147501   21296.240599
# 2         646.009738   40564.936531
# 3        2091.737298  836292.465368

# %% [markdown]
# Summary statistics for mean signal and variance within each cluster.

# %%
cre_parameter_all.groupby('cluster')[['mean_signal', 'var']].describe()
# Out:
#         mean_signal                                                         \
#               count       mean        std        min        25%        50%
# cluster
# 0          333357.0   3.092382   2.569199   0.271333   1.483222   2.140667
# 1           24191.0  20.162106   9.805483   2.520000  12.578333  18.167556
# 2            3812.0  72.148061  25.416722  33.723222  54.253611  64.463000
# 3             970.0  53.097032  45.735515   9.973889  26.903861  37.384667
#
#                                      var                                       \
#                75%         max     count         mean         std         min
# cluster
# 0         3.664222   19.075222  333357.0    14.610142   22.766626    0.267962
# 1        25.758722   51.543444   24191.0   208.506287  145.932315   18.761810
# 2        83.156639  251.171333    3812.0   394.619013  201.407389   81.644033
# 3        62.712028  696.593222     970.0  1374.526879  914.490276  813.147425
#
#
#                 25%          50%          75%           max
# cluster
# 0          2.530494     5.557787    15.515511    199.075219
# 1        105.762176   171.003817   261.306631    873.346213
# 2        242.282160   345.318453   515.801853   1160.542239
# 3        975.542016  1146.740707  1451.689840  15102.038410

# %% [markdown]
# <h3>Boxplot of mean ATACseq signal per cluster</h3>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=cre_parameter_all, x='cluster', y='mean_signal', color='violet')
plt.title('Mean ATAC signal per CRE cluster (ALL)')
plt.show()

# %% [markdown]
# <h3>Boxplot of ATACseq signal variance per cluster</h3>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(data=cre_parameter_all, x='cluster', y='var', color='violet')
plt.title('Varianz ATAC signal per CRE cluster (ALL)')
plt.show()

# %% [markdown]
# <p> After the four different clusters were compared and visualized in a boxplot, the following was observed:</p>
# Cluster 0 (333357.0 values): Very low mean and variance (mostly closed CREs).<br>Cluster 1 (24191.0 values): Low to medium mean and variance (weakly active CREs).<br>Cluster 3 (970.0 values): High mean and very high variance (strongly active and variable CREs).<br>Cluster 2 (3812.0 values): Very high mean and meidum to high variance (very strongly active CREs).<br>
# <br>Notably, almost all CREs are assigned to Cluster 0, by which it is indicated that most are kept inactive or closed across the differentiation of the γδ T-cell lineage.

# %% [markdown]
# <h3> Heatmap of average accessibility per γδ T-cell sample for each cluster

# %% [markdown]
# Adding Cluster Labels to ATACseq Data

# %%
ATAC_signal_all_numeric = ATAC_signal_all.set_index('ImmGenATAC1219.peakID') #ImmGenATAC1219.peakID als index so das cluster_parameter und ATAC daten gleichen index haben
ATAC_signal_all_numeric_cluster = ATAC_signal_all_numeric.copy()
ATAC_signal_all_numeric_cluster['cluster'] = cre_parameter_all['cluster'] #neue splate ATAC daten mit clustern von Cre parameter übernommen

ATAC_signal_all_numeric_cluster.head()
# Out:
#                        LTHSC.34-.BM  LTHSC.34+.BM  STHSC.150-.BM  \
# ImmGenATAC1219.peakID
# ImmGenATAC1219.peak_3          2.36          0.10           0.90
# ImmGenATAC1219.peak_4          0.41          0.10           0.11
# ImmGenATAC1219.peak_5          0.41          0.10           0.11
# ImmGenATAC1219.peak_6          2.36          1.64           1.85
# ImmGenATAC1219.peak_7          0.41          0.10           0.11
#
#                        MPP4.135+.BM  proB.CLP.BM  proB.FrA.BM  proB.FrBC.BM  \
# ImmGenATAC1219.peakID
# ImmGenATAC1219.peak_3          0.11         0.47         0.10          0.50
# ImmGenATAC1219.peak_4          0.11         0.79         0.40          0.50
# ImmGenATAC1219.peak_5          0.11         0.47         0.34          1.78
# ImmGenATAC1219.peak_6          1.58         1.12         0.34          0.42
# ImmGenATAC1219.peak_7          0.11         0.11         1.34          0.90
#
#                        preB.FrD.BM  B.FrE.BM  B1b.PC  ...  DC.8+.Sp  \
# ImmGenATAC1219.peakID                                 ...
# ImmGenATAC1219.peak_3         1.17      0.32    0.14  ...      0.54
# ImmGenATAC1219.peak_4         2.23      0.80    0.14  ...      1.83
# ImmGenATAC1219.peak_5         1.17      0.32    0.60  ...      0.10
# ImmGenATAC1219.peak_6         0.13      0.80    0.60  ...      0.29
# ImmGenATAC1219.peak_7         1.69      0.80    0.60  ...      1.93
#
#                        DC.pDC.Sp  DC.103+11b+.SI  DC.103+11b-.SI  FRC.SLN  \
# ImmGenATAC1219.peakID
# ImmGenATAC1219.peak_3       2.72            0.95            0.11    63.38
# ImmGenATAC1219.peak_4       0.66            0.11            0.92    13.50
# ImmGenATAC1219.peak_5       0.66            1.79            0.51     0.92
# ImmGenATAC1219.peak_6       0.23            0.89            0.11     0.53
# ImmGenATAC1219.peak_7       0.59            0.11            1.39     2.58
#
#                        IAP.SLN  BEC.SLN  LEC.SLN  Ep.MEChi.Th  cluster
# ImmGenATAC1219.peakID
# ImmGenATAC1219.peak_3     8.92     1.33     1.04         0.11        0
# ImmGenATAC1219.peak_4     0.98     1.28     1.04         0.11        0
# ImmGenATAC1219.peak_5     0.75     1.33     1.61         4.50        0
# ImmGenATAC1219.peak_6     1.40     0.90     2.87         9.09        0
# ImmGenATAC1219.peak_7     0.75     2.30     2.34        11.02        0
#
# [5 rows x 91 columns]

# %% [markdown]
# Grouping ATACseq data by Cluster Assignments

# %%
cluster_all_mean = (
    ATAC_signal_all_numeric_cluster
    .groupby('cluster')
    .mean()
)
cluster_all_mean
# Out:
#          LTHSC.34-.BM  LTHSC.34+.BM  STHSC.150-.BM  MPP4.135+.BM  proB.CLP.BM  \
# cluster
# 0            3.155981      3.257074       3.243495      3.218713     3.129560
# 1           18.462804     19.516295      20.377810     21.353618    21.909168
# 2           67.584488     71.182046      70.366461     69.795719    72.043434
# 3           51.860320     54.220392      55.858124     65.661474    65.048701
#
#          proB.FrA.BM  proB.FrBC.BM  preB.FrD.BM   B.FrE.BM     B1b.PC  ...  \
# cluster                                                                ...
# 0           3.129481      3.172323     3.143030   3.039362   2.975061  ...
# 1          21.758629     20.097681    20.041519  20.402948  20.615739  ...
# 2          73.571351     71.327471    68.942610  72.458801  70.731603  ...
# 3          63.905278     55.066392    49.662505  50.613691  57.803103  ...
#
#           DC.4+.Sp   DC.8+.Sp  DC.pDC.Sp  DC.103+11b+.SI  DC.103+11b-.SI  \
# cluster
# 0         3.181673   3.250565   3.227038        3.212819        3.191375
# 1        20.672322  19.226087  19.301102       20.349484       20.455864
# 2        74.524423  74.732836  68.303358       73.602259       75.627385
# 3        52.557577  50.226381  58.452216       48.703021       48.140825
#
#            FRC.SLN    IAP.SLN    BEC.SLN    LEC.SLN  Ep.MEChi.Th
# cluster
# 0         3.640173   3.136949   3.269868   3.422551     3.507279
# 1        13.302361  20.307224  16.143858  13.737686    16.060342
# 2        66.350766  75.739848  71.230937  63.478526    73.131818
# 3        35.720093  46.620670  38.159928  41.810742    39.427485
#
# [4 rows x 90 columns]

# %% [markdown]
# Heatmap: Mean accessibility per cell sample for each cluster

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
sns.heatmap(
    cluster_all_mean, #Zeilen --> x-Achse, Spalten --> y-Achse, cluster spalte index nicht mitgenommen
    cmap="viridis",
    xticklabels=True
)

plt.title('Mean accessibility per cell sample for each CRE cluster')
plt.xlabel('All cell samples')
plt.ylabel('CRE cluster')

plt.xticks(rotation=90, fontsize=8)
plt.show()

# %% [markdown]
# The mean accessibility across all available cell types is visualized by the heatmap. It is confirmed that closed chromatin is captured by Cluster 0, mostly closed regions are represented by Cluster 1, and higher mean accessibility and variability are exhibited by Clusters 2 and 3.
#
# However, due to the high cellular diversity, lineage-specific dynamics are visually lost. This is contrasted by the heatmap specifically for the γδ T-cell lineage, where clear shifts between cell types are visible.

# %% [markdown]
# ## Clusters compared by signal strength: all cells vs linage-specific γδ T-cells

# %%
cre_parameter_all['cluster'].value_counts(normalize=True) #normalize=True: W-keit
# Out:
# cluster
# 0    0.920037
# 1    0.066765
# 2    0.010521
# 3    0.002677
# Name: proportion, dtype: float64

# %%
cre_parameter['cluster'].value_counts(normalize=True) #normalize=True: W-keit
# Out:
# cluster
# 0    0.925521
# 3    0.061623
# 2    0.009916
# 1    0.002939
# Name: proportion, dtype: float64

# %% [markdown]
# Both globally and within the cell lineages, 93% of the CREs are distributed across the clusters in the low-activity and low-variability clusters, and around 1% are in the high-activity and high-variability clusters.

# %% [markdown]
# ## Conclusion
#
# <div class="alert alert-block alert-info">
# For CRE classification by signal strength and variability, elements were clustered based on their mean accessibility and variability across different cell types. CREs were separated by this in a very straightforward way, primarily by signal strength (low to high) and variability (constant to highly fluctuating). Thus, a distinction is mainly made by the clusters between “closed, low signal” and “open, high signal” regions, by which only a few patterns are captured (e.g., the sharp drop in accessibility specifically at the T.DN4.Th stage).
#
# Moreover, because the vast majority of peaks are assigned to the inactive Cluster 0, detailed lineage-specific patterns fail to be captured by this approach. To identify γδ T-cell specific CREs, the hierarchical clustering from Section 1.3 is more effective, as peaks are directly grouped by their sample-specific correlation profiles.
# </div>
