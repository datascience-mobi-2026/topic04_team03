# %% [markdown]
# # General notebook preparation: Libaries and Datasets

# %% [markdown]
# At the beginning, the basic libaries that we work with need to be imported. That includes pandas for data read out, matplot libary for basic plotting, numpy for numeric operations, seaborn for advanced plotting and scipy stats for statistical calculations.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import scipy.stats as stats
from pathlib import Path

# %% [markdown]
# # ATAC-sequencing Dataset: Introduction

# %% [markdown]
# Then, the ATAC-sequencing dataset is read out using the path-operator. By using path, it is ensured that regardless of processor differences (Mac, Windows, etc.), the same path will be used each time when accessing the dataset.

# %%
ATAC_path = Path('data') / 'ImmGenATAC18_AllOCRsInfo.csv'
ATAC_data = pd.read_csv(ATAC_path)

df = pd.read_csv("data/ImmGenATAC18_AllOCRsInfo.csv")
df.head()
# Out:
#    ImmGenATAC1219.peakID chrom   Summit  mm10.60way.phastCons_scores  \
# 0  ImmGenATAC1219.peak_1  chr1  3020786                         0.00
# 1  ImmGenATAC1219.peak_2  chr1  3087226                         0.00
# 2  ImmGenATAC1219.peak_3  chr1  3120109                         0.07
# 3  ImmGenATAC1219.peak_4  chr1  3121485                         0.15
# 4  ImmGenATAC1219.peak_5  chr1  3372787                         0.03
#
#    _-log10_bestPvalue  Included.in.systematic.analysis  TSS  \
# 0                0.56                              NaN  NaN
# 1                0.50                              NaN  NaN
# 2               10.80                              1.0  NaN
# 3                3.02                              1.0  NaN
# 4                1.31                              NaN  NaN
#
#   genes.within.100Kb  LTHSC.34-.BM  LTHSC.34+.BM  ...  DC.4+.Sp  DC.8+.Sp  \
# 0                NaN          0.41          0.71  ...      0.10      0.10
# 1                NaN          0.41          1.64  ...      1.70      0.10
# 2                NaN          2.36          0.10  ...      0.87      0.54
# 3                NaN          0.41          0.10  ...      0.44      1.83
# 4                NaN          0.41          0.10  ...      0.44      0.10
#
#    DC.pDC.Sp  DC.103+11b+.SI  DC.103+11b-.SI  FRC.SLN  IAP.SLN  BEC.SLN  \
# 0       3.19            1.37            0.52     1.27     0.10     0.57
# 1       1.41            0.47            0.11     0.92     0.98     2.16
# 2       2.72            0.95            0.11    63.38     8.92     1.33
# 3       0.66            0.11            0.92    13.50     0.98     1.28
# 4       0.66            1.79            0.51     0.92     0.75     1.33
#
#    LEC.SLN  Ep.MEChi.Th
# 0     3.27         1.41
# 1     2.34         0.94
# 2     1.04         0.11
# 3     1.04         0.11
# 4     1.61         4.50
#
# [5 rows x 98 columns]

# %% [markdown]
# **This is the ATAC-sequencing dataset from Yoshida et al. (2019) that we work with during this project.** <p>
# Each row (=entry) is a OCR peak. The set tells us how strong the peak is in each of the 89 immune cell types
# The data also includes Metadata for each of those peaks:
#
# - **ImmGenATAC1219.peakID** <br>
# Specific peak ID for each different signal peak
#
# - **chrom**
# Chromosome on which the OCR is located
#
# - **Summit**
# Genomic coordinate of the "peak summit"
# --> position with the strongest ATACseq signal within the OCR
#
# - **mm10 cons_score**
# as in "evolutionary conservation score"
# --> functional importance (highest value = 1.00)
#
# - **-log10_bestPvalue**
# remember: p-value measures likelihood of the result being just background noise (small p-value --> likely not background noise)
# --> kleiner log, großer p-value, wahrscheinlich relevant
#
# - **included in systematic analysis**
# Boolean / yes-no flag indicating whether the authors considered this OCR reliable enough for downstream analyses in the paper
#
# - **TSS**
# name of closest TSS gene
#
# - **genes within 100kb**
# just lists all the genes in that range as str

# %% [markdown]
# # ATAC-sequencing Dataset: Cleanup

# %% [markdown]
# Before moving on with bioinformatical analysis, the ATAC-dataset needs to be fully cleaned and pre-processed to avoid systematic errors. A primary data cleanup has already been taken care of by Yoshida et al., but there is more to be concious about.

# %% [markdown]
# ## Handling Missing Values

# %% [markdown]
# First, we will take a look at missing values (NaN) and analyse, whether some of them are accidental and need to be taken care of.

# %%
missing_value = ATAC_data.isnull().sum()
missing_value[missing_value > 0]
# Out:
# Included.in.systematic.analysis    177716
# TSS                                498303
# genes.within.100Kb                  84885
# dtype: int64

# %%
missing_value.head(10)
# Out:
# ImmGenATAC1219.peakID                   0
# chrom                                   0
# Summit                                  0
# mm10.60way.phastCons_scores             0
# _-log10_bestPvalue                      0
# Included.in.systematic.analysis    177716
# TSS                                498303
# genes.within.100Kb                  84885
# LTHSC.34-.BM                            0
# LTHSC.34+.BM                            0
# dtype: int64

# %% [markdown]
# We only have missing values (NaN) in three different columns. In all three categories, however, ‘NaN’ does not indicate a genuinely missing value, but provides us with useful information. The NaNs *Included.in.systematic.analysis*, for example, tell us which ATAC peaks were not used in the research team's subsequent analysis.
# All NAs in *TSS* mark distal enhancers and genes that have no gene in their immediate vicinity (100 kbs) are also marked with NaN. <p>
# Therefore, no missing values need to be replaced or deleted.

# %% [markdown]
# ## P-Value Filtering: Removing less reliable signal peaks (low variance, low signal, etc.)

# %% [markdown]
# For this project, it was decided to select a general threshold of **0.05** for p-values, a threshold that is often used in data analysis. All p-values above that number will be removed from further analysis, since they may not be statistically relevant. For this reason, we create a new dataset called "ATAC_pfiltered", which we will use from here on. <br> It is important to note that p-values are expressed in log10-form, which means that a high p-value corresponds to a low value of log10 (p-value).

# %%
ATAC_pfiltered = ATAC_data[ATAC_data['_-log10_bestPvalue'] > -np.log10(0.05)]
ATAC_pfiltered
# Out:
#              ImmGenATAC1219.peakID chrom    Summit  \
# 2            ImmGenATAC1219.peak_3  chr1   3120109
# 3            ImmGenATAC1219.peak_4  chr1   3121485
# 4            ImmGenATAC1219.peak_5  chr1   3372787
# 5            ImmGenATAC1219.peak_6  chr1   3399217
# 6            ImmGenATAC1219.peak_7  chr1   3400115
# ...                            ...   ...       ...
# 512588  ImmGenATAC1219.peak_512589  chrY  90811728
# 512589  ImmGenATAC1219.peak_512590  chrY  90812084
# 512590  ImmGenATAC1219.peak_512591  chrY  90812450
# 512591  ImmGenATAC1219.peak_512592  chrY  90812906
# 512594  ImmGenATAC1219.peak_512595  chrY  90828985
#
#         mm10.60way.phastCons_scores  _-log10_bestPvalue  \
# 2                              0.07               10.80
# 3                              0.15                3.02
# 4                              0.03                1.31
# 5                              0.06                2.39
# 6                              0.44                2.57
# ...                             ...                 ...
# 512588                         0.00                2.33
# 512589                         0.00                3.12
# 512590                         0.00                3.99
# 512591                         0.00                3.21
# 512594                         0.00                1.41
#
#         Included.in.systematic.analysis  TSS genes.within.100Kb  LTHSC.34-.BM  \
# 2                                   1.0  NaN                NaN          2.36
# 3                                   1.0  NaN                NaN          0.41
# 4                                   NaN  NaN                NaN          0.41
# 5                                   1.0  NaN                NaN          2.36
# 6                                   1.0  NaN                NaN          0.41
# ...                                 ...  ...                ...           ...
# 512588                              1.0  NaN              Erdr1          0.41
# 512589                              1.0  NaN              Erdr1          2.36
# 512590                              1.0  NaN              Erdr1          4.37
# 512591                              1.0  NaN              Erdr1          0.41
# 512594                              NaN  NaN              Erdr1          0.41
#
#         LTHSC.34+.BM  ...  DC.4+.Sp  DC.8+.Sp  DC.pDC.Sp  DC.103+11b+.SI  \
# 2               0.10  ...      0.87      0.54       2.72            0.95
# 3               0.10  ...      0.44      1.83       0.66            0.11
# 4               0.10  ...      0.44      0.10       0.66            1.79
# 5               1.64  ...      1.34      0.29       0.23            0.89
# 6               0.10  ...      0.87      1.93       0.59            0.11
# ...              ...  ...       ...       ...        ...             ...
# 512588          7.41  ...      4.98      4.47       2.83            4.93
# 512589          8.79  ...      4.03      4.07       5.87            5.36
# 512590          8.79  ...      3.81      3.34       4.27            6.73
# 512591          7.41  ...      4.28      5.55       4.15            6.88
# 512594          0.71  ...      1.26      0.72       0.71            1.40
#
#         DC.103+11b-.SI  FRC.SLN  IAP.SLN  BEC.SLN  LEC.SLN  Ep.MEChi.Th
# 2                 0.11    63.38     8.92     1.33     1.04         0.11
# 3                 0.92    13.50     0.98     1.28     1.04         0.11
# 4                 0.51     0.92     0.75     1.33     1.61         4.50
# 5                 0.11     0.53     1.40     0.90     2.87         9.09
# 6                 1.39     2.58     0.75     2.30     2.34        11.02
# ...                ...      ...      ...      ...      ...          ...
# 512588            4.92     5.13     9.13     2.21     6.53         6.11
# 512589            3.99     7.12     3.57     2.64     5.59         3.64
# 512590            5.53     7.21     5.96     5.17     6.53         6.11
# 512591            7.16     6.21     8.75     6.83     8.14         4.64
# 512594            0.52     0.85     1.37     0.57     0.11         0.50
#
# [362330 rows x 98 columns]

# %%
len(ATAC_pfiltered)
# Out:
# 362330

# %%
len(ATAC_data[ATAC_data['_-log10_bestPvalue'] <= -np.log10(0.05)])
# Out:
# 150265

# %% [markdown]
# One-third (~150.000) of the values have a p-value greater than 0.05. It could be reasonable to remove these values from downstream analysis. Before doing that however, it could be wise to investigate whether Yoshida et al. excluded these values form their investigation as well.

# %%
ATAC_NA_pvalue = ATAC_data[
    (ATAC_data['_-log10_bestPvalue'] < -np.log10(0.05)) &
    (ATAC_data['Included.in.systematic.analysis'].isnull())
]


len(ATAC_NA_pvalue)
# Out:
# 150265

# %% [markdown]
# All values with a p-value greater than 0.05 were also excluded from the analysis in Yoshida’s paper (150265). Furthermore, Yoshida et al. removed further values following filtering processes based on criteria they themselves defined. It would therefore make sense for our analysis to apply this threshold of 0.05, as these values were, at the very least, also removed from Yoshida’s paper.

# %% [markdown]
# ## Blacklist Filtering

# %% [markdown]
# In the paper by Yoshida et al. it was mentioned that there were certain blacklisted genomic regions. Because of that, we decided to check whether these blacklisted regions were already removed from the data set.

# %%
ATAC_path_blacklist = Path('data') / 'mm10.blacklist(2).bed'
ATAC_data_blacklist = pd.read_csv(ATAC_path_blacklist)

ATAC_data_blacklist
#df2.__len__()
# Out:
#         chr10\t3110060\t3110270
# 0     chr10\t22142530\t22142880
# 1     chr10\t22142830\t22143070
# 2     chr10\t58223870\t58224100
# 3     chr10\t58225260\t58225500
# 4     chr10\t58228320\t58228520
# ..                          ...
# 158      chr9\t3038050\t3038300
# 159    chr9\t24541940\t24542200
# 160    chr9\t35305120\t35305620
# 161  chr9\t110281190\t110281400
# 162  chr9\t123872950\t123873160
#
# [163 rows x 1 columns]

# %%
cols = [
    "gene_name",
    "transcript_name",
    "chrom",
    "strand",
    "txStart",
    "txEnd",
    "cdsStart",
    "cdsEnd",
    "exonCount",
    "exonStarts",
    "exonEnds"
]

ATAC_path_genanno = Path("data") / "Gene annotations.txt"

Gene_annotations = pd.read_csv(
    ATAC_path_genanno,
    sep="\t",
    names=cols
)

Gene_annotations.head()
# Out:
#   gene_name transcript_name chrom strand    txStart      txEnd   cdsStart  \
# 0    Wdsub1    NM_001159636  chr2      -   59855193   59882606   59855270
# 1     Rbm18    NM_001159635  chr2      -   36116078   36136704   36117814
# 2    Prrc2b    NM_001159634  chr2      +   32151147   32234537   32182511
# 3     Ildr2    NM_001164528  chr1      +  166254138  166316832  166254375
# 4     Perm1       NM_172417  chr4      +  156215926  156221307  156217000
#
#       cdsEnd  exonCount                                         exonStarts  \
# 0   59878527         11  59855193,59858609,59861560,59862619,59862816,5...
# 1   36134247          6  36116078,36120812,36122851,36127214,36134134,3...
# 2   32230742         32  32151147,32182457,32183122,32185344,32187480,3...
# 3  166310795         10  166254138,166269304,166270498,166291415,166294...
# 4  156220222          4           156215926,156216716,156219740,156220109,
#
#                                             exonEnds
# 0  59855275,59858750,59861737,59862726,59862857,5...
# 1  36117974,36120898,36122938,36127251,36134263,3...
# 2  32151291,32182626,32183300,32185447,32187553,3...
# 3  166254466,166269637,166270618,166291472,166294...
# 4           156215975,156219185,156219866,156221307,

# %%
Gene_annotations[Gene_annotations["txStart"] == 59855193]
(Gene_annotations['txStart'] == 59855193).any() #postitive control: exits
# Out:
# np.True_

# %%
Gene_annotations[Gene_annotations["txStart"] == 24541940]
#or
(Gene_annotations["txStart"] == 24541940).any() #start of example blacklisted gene: not found
# Out:
# np.False_

# %% [markdown]
# We extracted the blacklisted genes as a table and then compared their accession numbers with those of the annotated genes in the gene annotations dataset. The blacklisted genes do not appear in the gene annotations dataset; it can therefore be assumed that these blacklisted genes were removed at the start of the data clean-up carried out by Yoshida et al.

# %% [markdown]
# With that, our ATAC-datset is processed and properly cleaned-up, though the most deciding steps have already been done by Yoshida et al. <p> **Now data anlysis can begin!**

# %% [markdown]
# # Should any peaks be filtered out due to insufficient signal?

# %% [markdown]
# The data were obtained from a prefiltered and systematically analyzed OCR set. As described in the paper by Yoshida et al., the OCRs were sorted out, quantified, and normalized, thereby filtering out blacklisted genomic regions and chromosome homologous regions, thus removing possible artifacts.  <br>
# When the QC data (mmc1 data) were examined, sufficient sample quality was observed, so no additional broad filtering of peaks due to insufficient signal was necessary.<br>
# Additionally, all data with a p value under 0.05 (5%) were removed, setting a threshold for unreliable data and removing possible OCRs caused by background noise.<br>
# When the minimum ATAC signal across the OCR was checked, there were no peaks that had a signal of zero. There was no evidence for completely absent signals, and low‑signal peaks will be needed for analyzing the accessibility.
#
# - notebook for QC data exploration (03_Exploration_of_ATACseq_QC_Data.ipynb)

# %% [markdown]
# # Creating a file for the filtered ATACseq data and ATAC_Tgd

# %% [markdown]
# ## ATAC_pfiltered

# %%
from pathlib import Path
ATAC_path = Path('data') / 'ImmGenATAC18_AllOCRsInfo.csv'
ATAC_data = pd.read_csv(ATAC_path)
ATAC_pfiltered = ATAC_data[ATAC_data['_-log10_bestPvalue'] > -np.log10(0.05)]
ATAC_pfiltered
# Out:
#              ImmGenATAC1219.peakID chrom    Summit  \
# 2            ImmGenATAC1219.peak_3  chr1   3120109
# 3            ImmGenATAC1219.peak_4  chr1   3121485
# 4            ImmGenATAC1219.peak_5  chr1   3372787
# 5            ImmGenATAC1219.peak_6  chr1   3399217
# 6            ImmGenATAC1219.peak_7  chr1   3400115
# ...                            ...   ...       ...
# 512588  ImmGenATAC1219.peak_512589  chrY  90811728
# 512589  ImmGenATAC1219.peak_512590  chrY  90812084
# 512590  ImmGenATAC1219.peak_512591  chrY  90812450
# 512591  ImmGenATAC1219.peak_512592  chrY  90812906
# 512594  ImmGenATAC1219.peak_512595  chrY  90828985
#
#         mm10.60way.phastCons_scores  _-log10_bestPvalue  \
# 2                              0.07               10.80
# 3                              0.15                3.02
# 4                              0.03                1.31
# 5                              0.06                2.39
# 6                              0.44                2.57
# ...                             ...                 ...
# 512588                         0.00                2.33
# 512589                         0.00                3.12
# 512590                         0.00                3.99
# 512591                         0.00                3.21
# 512594                         0.00                1.41
#
#         Included.in.systematic.analysis  TSS genes.within.100Kb  LTHSC.34-.BM  \
# 2                                   1.0  NaN                NaN          2.36
# 3                                   1.0  NaN                NaN          0.41
# 4                                   NaN  NaN                NaN          0.41
# 5                                   1.0  NaN                NaN          2.36
# 6                                   1.0  NaN                NaN          0.41
# ...                                 ...  ...                ...           ...
# 512588                              1.0  NaN              Erdr1          0.41
# 512589                              1.0  NaN              Erdr1          2.36
# 512590                              1.0  NaN              Erdr1          4.37
# 512591                              1.0  NaN              Erdr1          0.41
# 512594                              NaN  NaN              Erdr1          0.41
#
#         LTHSC.34+.BM  ...  DC.4+.Sp  DC.8+.Sp  DC.pDC.Sp  DC.103+11b+.SI  \
# 2               0.10  ...      0.87      0.54       2.72            0.95
# 3               0.10  ...      0.44      1.83       0.66            0.11
# 4               0.10  ...      0.44      0.10       0.66            1.79
# 5               1.64  ...      1.34      0.29       0.23            0.89
# 6               0.10  ...      0.87      1.93       0.59            0.11
# ...              ...  ...       ...       ...        ...             ...
# 512588          7.41  ...      4.98      4.47       2.83            4.93
# 512589          8.79  ...      4.03      4.07       5.87            5.36
# 512590          8.79  ...      3.81      3.34       4.27            6.73
# 512591          7.41  ...      4.28      5.55       4.15            6.88
# 512594          0.71  ...      1.26      0.72       0.71            1.40
#
#         DC.103+11b-.SI  FRC.SLN  IAP.SLN  BEC.SLN  LEC.SLN  Ep.MEChi.Th
# 2                 0.11    63.38     8.92     1.33     1.04         0.11
# 3                 0.92    13.50     0.98     1.28     1.04         0.11
# 4                 0.51     0.92     0.75     1.33     1.61         4.50
# 5                 0.11     0.53     1.40     0.90     2.87         9.09
# 6                 1.39     2.58     0.75     2.30     2.34        11.02
# ...                ...      ...      ...      ...      ...          ...
# 512588            4.92     5.13     9.13     2.21     6.53         6.11
# 512589            3.99     7.12     3.57     2.64     5.59         3.64
# 512590            5.53     7.21     5.96     5.17     6.53         6.11
# 512591            7.16     6.21     8.75     6.83     8.14         4.64
# 512594            0.52     0.85     1.37     0.57     0.11         0.50
#
# [362330 rows x 98 columns]

# %% [markdown]
# for not having to apply the filtering every time

# %%
ATAC_pfiltered.to_csv('data/ATAC_pfiltered.csv', index=False, header=True)
ATAC_pfiltered_check = pd.read_csv('data/ATAC_pfiltered.csv')
ATAC_pfiltered_check
# Out:
#              ImmGenATAC1219.peakID chrom    Summit  \
# 0            ImmGenATAC1219.peak_3  chr1   3120109
# 1            ImmGenATAC1219.peak_4  chr1   3121485
# 2            ImmGenATAC1219.peak_5  chr1   3372787
# 3            ImmGenATAC1219.peak_6  chr1   3399217
# 4            ImmGenATAC1219.peak_7  chr1   3400115
# ...                            ...   ...       ...
# 362325  ImmGenATAC1219.peak_512589  chrY  90811728
# 362326  ImmGenATAC1219.peak_512590  chrY  90812084
# 362327  ImmGenATAC1219.peak_512591  chrY  90812450
# 362328  ImmGenATAC1219.peak_512592  chrY  90812906
# 362329  ImmGenATAC1219.peak_512595  chrY  90828985
#
#         mm10.60way.phastCons_scores  _-log10_bestPvalue  \
# 0                              0.07               10.80
# 1                              0.15                3.02
# 2                              0.03                1.31
# 3                              0.06                2.39
# 4                              0.44                2.57
# ...                             ...                 ...
# 362325                         0.00                2.33
# 362326                         0.00                3.12
# 362327                         0.00                3.99
# 362328                         0.00                3.21
# 362329                         0.00                1.41
#
#         Included.in.systematic.analysis  TSS genes.within.100Kb  LTHSC.34-.BM  \
# 0                                   1.0  NaN                NaN          2.36
# 1                                   1.0  NaN                NaN          0.41
# 2                                   NaN  NaN                NaN          0.41
# 3                                   1.0  NaN                NaN          2.36
# 4                                   1.0  NaN                NaN          0.41
# ...                                 ...  ...                ...           ...
# 362325                              1.0  NaN              Erdr1          0.41
# 362326                              1.0  NaN              Erdr1          2.36
# 362327                              1.0  NaN              Erdr1          4.37
# 362328                              1.0  NaN              Erdr1          0.41
# 362329                              NaN  NaN              Erdr1          0.41
#
#         LTHSC.34+.BM  ...  DC.4+.Sp  DC.8+.Sp  DC.pDC.Sp  DC.103+11b+.SI  \
# 0               0.10  ...      0.87      0.54       2.72            0.95
# 1               0.10  ...      0.44      1.83       0.66            0.11
# 2               0.10  ...      0.44      0.10       0.66            1.79
# 3               1.64  ...      1.34      0.29       0.23            0.89
# 4               0.10  ...      0.87      1.93       0.59            0.11
# ...              ...  ...       ...       ...        ...             ...
# 362325          7.41  ...      4.98      4.47       2.83            4.93
# 362326          8.79  ...      4.03      4.07       5.87            5.36
# 362327          8.79  ...      3.81      3.34       4.27            6.73
# 362328          7.41  ...      4.28      5.55       4.15            6.88
# 362329          0.71  ...      1.26      0.72       0.71            1.40
#
#         DC.103+11b-.SI  FRC.SLN  IAP.SLN  BEC.SLN  LEC.SLN  Ep.MEChi.Th
# 0                 0.11    63.38     8.92     1.33     1.04         0.11
# 1                 0.92    13.50     0.98     1.28     1.04         0.11
# 2                 0.51     0.92     0.75     1.33     1.61         4.50
# 3                 0.11     0.53     1.40     0.90     2.87         9.09
# 4                 1.39     2.58     0.75     2.30     2.34        11.02
# ...                ...      ...      ...      ...      ...          ...
# 362325            4.92     5.13     9.13     2.21     6.53         6.11
# 362326            3.99     7.12     3.57     2.64     5.59         3.64
# 362327            5.53     7.21     5.96     5.17     6.53         6.11
# 362328            7.16     6.21     8.75     6.83     8.14         4.64
# 362329            0.52     0.85     1.37     0.57     0.11         0.50
#
# [362330 rows x 98 columns]

# %% [markdown]
# ## ATAC_Tgd
# This dataset is a subunit of ATAC_pfiltered, but only with the Tgd-cells cells.

# %%
Tgd_cells_annot = [
        "ImmGenATAC1219.peakID",
        "chrom",
        "Summit",
        "mm10.60way.phastCons_scores",
        "_-log10_bestPvalue",
        "Included.in.systematic.analysis",
        "TSS", 
        "genes.within.100Kb",
        "MPP4.135+.BM",
        "preT.DN1.Th",
        "preT.DN2a.Th",
        "preT.DN2b.Th",
        "preT.DN3.Th",
        "T.DN4.Th",
        "Tgd.g1.1+d1.24a+.Th",
        "Tgd.g2+d1.24a+.Th",
        "Tgd.g2+d17.24a+.Th",
        "Tgd.Sp",
        "Tgd.g1.1+d1.LN",
        "Tgd.g2+d1.LN",
        "Tgd.g2+d17.LN"
    ]

ATAC_Tgd = ATAC_pfiltered[Tgd_cells_annot].copy()
ATAC_Tgd
# Out:
#              ImmGenATAC1219.peakID chrom    Summit  \
# 2            ImmGenATAC1219.peak_3  chr1   3120109
# 3            ImmGenATAC1219.peak_4  chr1   3121485
# 4            ImmGenATAC1219.peak_5  chr1   3372787
# 5            ImmGenATAC1219.peak_6  chr1   3399217
# 6            ImmGenATAC1219.peak_7  chr1   3400115
# ...                            ...   ...       ...
# 512588  ImmGenATAC1219.peak_512589  chrY  90811728
# 512589  ImmGenATAC1219.peak_512590  chrY  90812084
# 512590  ImmGenATAC1219.peak_512591  chrY  90812450
# 512591  ImmGenATAC1219.peak_512592  chrY  90812906
# 512594  ImmGenATAC1219.peak_512595  chrY  90828985
#
#         mm10.60way.phastCons_scores  _-log10_bestPvalue  \
# 2                              0.07               10.80
# 3                              0.15                3.02
# 4                              0.03                1.31
# 5                              0.06                2.39
# 6                              0.44                2.57
# ...                             ...                 ...
# 512588                         0.00                2.33
# 512589                         0.00                3.12
# 512590                         0.00                3.99
# 512591                         0.00                3.21
# 512594                         0.00                1.41
#
#         Included.in.systematic.analysis  TSS genes.within.100Kb  MPP4.135+.BM  \
# 2                                   1.0  NaN                NaN          0.11
# 3                                   1.0  NaN                NaN          0.11
# 4                                   NaN  NaN                NaN          0.11
# 5                                   1.0  NaN                NaN          1.58
# 6                                   1.0  NaN                NaN          0.11
# ...                                 ...  ...                ...           ...
# 512588                              1.0  NaN              Erdr1          3.49
# 512589                              1.0  NaN              Erdr1          2.15
# 512590                              1.0  NaN              Erdr1          2.58
# 512591                              1.0  NaN              Erdr1          3.04
# 512594                              NaN  NaN              Erdr1          3.49
#
#         preT.DN1.Th  ...  preT.DN2b.Th  preT.DN3.Th  T.DN4.Th  \
# 2              0.40  ...          0.11         0.10      0.35
# 3              0.46  ...          0.47         0.10      0.58
# 4              0.77  ...          1.34         1.69      0.34
# 5              0.77  ...          0.47         1.02      0.10
# 6              0.40  ...          0.47         0.10      0.58
# ...             ...  ...           ...          ...       ...
# 512588         2.09  ...          4.17         7.10      6.93
# 512589         1.76  ...          2.55         4.00     10.15
# 512590         3.32  ...          3.37         4.55      8.41
# 512591         3.56  ...          8.18        10.40     15.50
# 512594         1.61  ...          1.78         1.02      2.38
#
#         Tgd.g1.1+d1.24a+.Th  Tgd.g2+d1.24a+.Th  Tgd.g2+d17.24a+.Th  Tgd.Sp  \
# 2                      0.11               0.76                0.53    1.46
# 3                      0.11               0.29                0.53    0.51
# 4                      1.39               1.58                3.16    0.51
# 5                      1.33               0.10                1.48    0.15
# 6                      1.33               1.27                1.11    0.51
# ...                     ...                ...                 ...     ...
# 512588                 9.58               9.65               11.37    3.98
# 512589                 6.88              20.55                8.96    2.34
# 512590                 8.61              19.64                8.96    3.61
# 512591                12.38              15.54               10.92    3.52
# 512594                 3.23               5.39                4.11    4.72
#
#         Tgd.g1.1+d1.LN  Tgd.g2+d1.LN  Tgd.g2+d17.LN
# 2                 0.11          0.12           0.86
# 3                 0.11          0.70           0.13
# 4                 0.99          0.12           0.73
# 5                 0.11          1.26           0.73
# 6                 2.86          0.70           0.73
# ...                ...           ...            ...
# 512588           15.78          5.85          19.30
# 512589           10.00          9.77          10.93
# 512590           13.42         14.05           9.01
# 512591           11.73          8.31          12.91
# 512594            1.62          2.68           1.48
#
# [362330 rows x 21 columns]

# %%
ATAC_Tgd.to_csv('data/ATAC_seq_gd_anot.csv', index=False, header=True)
ATAC_Tgd_check = pd.read_csv('data/ATAC_seq_gd_anot.csv')
ATAC_Tgd_check
# Out:
#              ImmGenATAC1219.peakID chrom    Summit  \
# 0            ImmGenATAC1219.peak_3  chr1   3120109
# 1            ImmGenATAC1219.peak_4  chr1   3121485
# 2            ImmGenATAC1219.peak_5  chr1   3372787
# 3            ImmGenATAC1219.peak_6  chr1   3399217
# 4            ImmGenATAC1219.peak_7  chr1   3400115
# ...                            ...   ...       ...
# 362325  ImmGenATAC1219.peak_512589  chrY  90811728
# 362326  ImmGenATAC1219.peak_512590  chrY  90812084
# 362327  ImmGenATAC1219.peak_512591  chrY  90812450
# 362328  ImmGenATAC1219.peak_512592  chrY  90812906
# 362329  ImmGenATAC1219.peak_512595  chrY  90828985
#
#         mm10.60way.phastCons_scores  _-log10_bestPvalue  \
# 0                              0.07               10.80
# 1                              0.15                3.02
# 2                              0.03                1.31
# 3                              0.06                2.39
# 4                              0.44                2.57
# ...                             ...                 ...
# 362325                         0.00                2.33
# 362326                         0.00                3.12
# 362327                         0.00                3.99
# 362328                         0.00                3.21
# 362329                         0.00                1.41
#
#         Included.in.systematic.analysis  TSS genes.within.100Kb  MPP4.135+.BM  \
# 0                                   1.0  NaN                NaN          0.11
# 1                                   1.0  NaN                NaN          0.11
# 2                                   NaN  NaN                NaN          0.11
# 3                                   1.0  NaN                NaN          1.58
# 4                                   1.0  NaN                NaN          0.11
# ...                                 ...  ...                ...           ...
# 362325                              1.0  NaN              Erdr1          3.49
# 362326                              1.0  NaN              Erdr1          2.15
# 362327                              1.0  NaN              Erdr1          2.58
# 362328                              1.0  NaN              Erdr1          3.04
# 362329                              NaN  NaN              Erdr1          3.49
#
#         preT.DN1.Th  ...  preT.DN2b.Th  preT.DN3.Th  T.DN4.Th  \
# 0              0.40  ...          0.11         0.10      0.35
# 1              0.46  ...          0.47         0.10      0.58
# 2              0.77  ...          1.34         1.69      0.34
# 3              0.77  ...          0.47         1.02      0.10
# 4              0.40  ...          0.47         0.10      0.58
# ...             ...  ...           ...          ...       ...
# 362325         2.09  ...          4.17         7.10      6.93
# 362326         1.76  ...          2.55         4.00     10.15
# 362327         3.32  ...          3.37         4.55      8.41
# 362328         3.56  ...          8.18        10.40     15.50
# 362329         1.61  ...          1.78         1.02      2.38
#
#         Tgd.g1.1+d1.24a+.Th  Tgd.g2+d1.24a+.Th  Tgd.g2+d17.24a+.Th  Tgd.Sp  \
# 0                      0.11               0.76                0.53    1.46
# 1                      0.11               0.29                0.53    0.51
# 2                      1.39               1.58                3.16    0.51
# 3                      1.33               0.10                1.48    0.15
# 4                      1.33               1.27                1.11    0.51
# ...                     ...                ...                 ...     ...
# 362325                 9.58               9.65               11.37    3.98
# 362326                 6.88              20.55                8.96    2.34
# 362327                 8.61              19.64                8.96    3.61
# 362328                12.38              15.54               10.92    3.52
# 362329                 3.23               5.39                4.11    4.72
#
#         Tgd.g1.1+d1.LN  Tgd.g2+d1.LN  Tgd.g2+d17.LN
# 0                 0.11          0.12           0.86
# 1                 0.11          0.70           0.13
# 2                 0.99          0.12           0.73
# 3                 0.11          1.26           0.73
# 4                 2.86          0.70           0.73
# ...                ...           ...            ...
# 362325           15.78          5.85          19.30
# 362326           10.00          9.77          10.93
# 362327           13.42         14.05           9.01
# 362328           11.73          8.31          12.91
# 362329            1.62          2.68           1.48
#
# [362330 rows x 21 columns]
